# %%
from Bio.Seq import Seq
from Bio.Alphabet import IUPAC
import os

directory = os.fsencode("./Sequences")

filenames = []

def sample_num(filename):
    return int(filename.split("D")[1].split("_")[0])
    
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".seq"):
        filenames.append(filename)
        print(filename)
        
print()           
filenames = sorted(filenames, key = sample_num)
print(filenames)
print()
            
for filename in filenames:
    print(filename)
    f = open("./Sequences/" + filename, "r")
    nns_seq = f.read()
    nns_seq = Seq(nns_seq, IUPAC.ambiguous_dna)
    if "CGTTATTGATGAA" in nns_seq:
        split_sequence = nns_seq.split(sep="CGTTATTGATGAA")[1]
        nns_codon = split_sequence[0:3]
        nns_codon_check = split_sequence[3:6]
        print("Sequenced Codon: " + nns_codon)
        print("Check Codon: " + nns_codon_check)
        nns_codon_transcribed = nns_codon.transcribe()
        print("Transcribed Codon: " + nns_codon_transcribed)
        res_id = nns_codon_transcribed.translate()
        print("Mutant Residue: " + res_id + "\n")
    else:
        print("Matching string not found\n")
# Out:
# 87-D8_G11_083.seq
# 05-D2_E01_007.seq
# 86-D7_F11_085.seq
# 92-D13_D12_090.seq
# 18-D17_B03_029.seq
# 02-D19_B01_013.seq
# 90-D11_B12_094.seq
# 88-D9_H11_081.seq
# 06-D3_F01_005.seq
# 85-D6_E11_087.seq
# 93-D14_E12_088.seq
# 12-D10_D02_010.seq
# 15-D14_G02_004.seq
# 80-D1_H10_066.seq
# 13-D11_E02_008.seq
# 96-D17_H12_082.seq
# 82-D3_B11_093.seq
# 91-D12_C12_092.seq
# 81-D2_A11_095.seq
# 89-D10_A12_096.seq
# 10-D8_B02_014.seq
# 94-D15_F12_086.seq
# 07-D4_G01_003.seq
# 14-D13_F02_006.seq
# 17-D16_A03_031.seq
# 11-D9_C02_012.seq
# 09-D7_A02_016.seq
# 08-D5_H01_001.seq
# 84-D5_D11_089.seq
# 95-D16_G12_084.seq
# 04-D1_D01_009.seq
# 16-D15_H02_002.seq
# 03-D20_C01_011.seq
# 01-D18_A01_015.seq
# 83-D4_C11_091.seq
#
# ['80-D1_H10_066.seq', '04-D1_D01_009.seq', '05-D2_E01_007.seq', '81-D2_A11_095.seq', '06-D3_F01_005.seq', '82-D3_B11_093.seq', '07-D4_G01_003.seq', '83-D4_C11_091.seq', '08-D5_H01_001.seq', '84-D5_D11_089.seq', '85-D6_E11_087.seq', '86-D7_F11_085.seq', '09-D7_A02_016.seq', '87-D8_G11_083.seq', '10-D8_B02_014.seq', '88-D9_H11_081.seq', '11-D9_C02_012.seq', '12-D10_D02_010.seq', '89-D10_A12_096.seq', '90-D11_B12_094.seq', '13-D11_E02_008.seq', '91-D12_C12_092.seq', '92-D13_D12_090.seq', '14-D13_F02_006.seq', '93-D14_E12_088.seq', '15-D14_G02_004.seq', '94-D15_F12_086.seq', '16-D15_H02_002.seq', '17-D16_A03_031.seq', '95-D16_G12_084.seq', '18-D17_B03_029.seq', '96-D17_H12_082.seq', '01-D18_A01_015.seq', '02-D19_B01_013.seq', '03-D20_C01_011.seq']
#
# 80-D1_H10_066.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 04-D1_D01_009.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 05-D2_E01_007.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 81-D2_A11_095.seq
#
# Matching string not found
#
# 06-D3_F01_005.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 82-D3_B11_093.seq
# Sequenced Codon: GGG
# Check Codon: GAN
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 07-D4_G01_003.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 83-D4_C11_091.seq
# Sequenced Codon: GGG
# Check Codon: GAN
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 08-D5_H01_001.seq
# Sequenced Codon: ACG
# Check Codon: GAT
# Transcribed Codon: ACG
# Mutant Residue: T
#
# 84-D5_D11_089.seq
# Sequenced Codon: ACG
# Check Codon: GAN
# Transcribed Codon: ACG
# Mutant Residue: T
#
# 85-D6_E11_087.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 86-D7_F11_085.seq
# Sequenced Codon: TAG
# Check Codon: GAT
# Transcribed Codon: UAG
# Mutant Residue: *
#
# 09-D7_A02_016.seq
#
# Matching string not found
#
# 87-D8_G11_083.seq
# Sequenced Codon: GGG
# Check Codon: GAN
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 10-D8_B02_014.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 88-D9_H11_081.seq
# Sequenced Codon: GCG
# Check Codon: GAN
# Transcribed Codon: GCG
# Mutant Residue: A
#
# 11-D9_C02_012.seq
# Sequenced Codon: GCG
# Check Codon: GAT
# Transcribed Codon: GCG
# Mutant Residue: A
#
# 12-D10_D02_010.seq
# Sequenced Codon: TAG
# Check Codon: GAT
# Transcribed Codon: UAG
# Mutant Residue: *
#
# 89-D10_A12_096.seq
#
# Matching string not found
#
# 90-D11_B12_094.seq
#
# Matching string not found
#
# 13-D11_E02_008.seq
# Sequenced Codon: TAG
# Check Codon: GAT
# Transcribed Codon: UAG
# Mutant Residue: *
#
# 91-D12_C12_092.seq
#
# Matching string not found
#
# 92-D13_D12_090.seq
#
# Matching string not found
#
# 14-D13_F02_006.seq
# Sequenced Codon: CCG
# Check Codon: GAT
# Transcribed Codon: CCG
# Mutant Residue: P
#
# 93-D14_E12_088.seq
#
# Matching string not found
#
# 15-D14_G02_004.seq
# Sequenced Codon: ATC
# Check Codon: GAT
# Transcribed Codon: AUC
# Mutant Residue: I
#
# 94-D15_F12_086.seq
#
# Matching string not found
#
# 16-D15_H02_002.seq
# Sequenced Codon: TGG
# Check Codon: GAT
# Transcribed Codon: UGG
# Mutant Residue: W
#
# 17-D16_A03_031.seq
# Sequenced Codon: AGC
# Check Codon: GAT
# Transcribed Codon: AGC
# Mutant Residue: S
#
# 95-D16_G12_084.seq
# Sequenced Codon: AGC
# Check Codon: GAN
# Transcribed Codon: AGC
# Mutant Residue: S
#
# 18-D17_B03_029.seq
# Sequenced Codon: ACC
# Check Codon: GAT
# Transcribed Codon: ACC
# Mutant Residue: T
#
# 96-D17_H12_082.seq
# Sequenced Codon: ACC
# Check Codon: GAT
# Transcribed Codon: ACC
# Mutant Residue: T
#
# 01-D18_A01_015.seq
# Sequenced Codon: GGC
# Check Codon: GAT
# Transcribed Codon: GGC
# Mutant Residue: G
#
# 02-D19_B01_013.seq
# Sequenced Codon: ACG
# Check Codon: GAT
# Transcribed Codon: ACG
# Mutant Residue: T
#
# 03-D20_C01_011.seq
# Sequenced Codon: GAG
# Check Codon: GAT
# Transcribed Codon: GAG
# Mutant Residue: E
