# %%
from Bio.Seq import Seq
from Bio.Alphabet import IUPAC
import os

directory = os.fsencode("./Sequences")

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".seq"):
        print(filename)
        f = open("./Sequences/" + filename, "r")
        nns_seq = f.read()
        nns_seq = Seq(nns_seq, IUPAC.ambiguous_dna)
        split_sequence = nns_seq.split(sep="CGTTATTGATGAA")[1]
        nns_codon = split_sequence[0:3]
        nns_codon_check = split_sequence[3:6]
        print("Sequenced Codon: " + nns_codon)
        print("Check Codon: " + nns_codon_check)
        nns_codon_transcribed = nns_codon.transcribe()
        print("Transcribed Codon: " + nns_codon_transcribed)
        res_id = nns_codon_transcribed.translate()
        print("Mutant Residue: " + res_id + "\n")
# Out:
# 05-D2_E01_007.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 18-D17_B03_029.seq
# Sequenced Codon: ACC
# Check Codon: GAT
# Transcribed Codon: ACC
# Mutant Residue: T
#
# 02-D19_B01_013.seq
# Sequenced Codon: ACG
# Check Codon: GAT
# Transcribed Codon: ACG
# Mutant Residue: T
#
# 06-D3_F01_005.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 12-D10_D02_010.seq
# Sequenced Codon: TAG
# Check Codon: GAT
# Transcribed Codon: UAG
# Mutant Residue: *
#
# 15-D14_G02_004.seq
# Sequenced Codon: ATC
# Check Codon: GAT
# Transcribed Codon: AUC
# Mutant Residue: I
#
# 13-D11_E02_008.seq
# Sequenced Codon: TAG
# Check Codon: GAT
# Transcribed Codon: UAG
# Mutant Residue: *
#
# 10-D8_B02_014.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 07-D4_G01_003.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 14-D13_F02_006.seq
# Sequenced Codon: CCG
# Check Codon: GAT
# Transcribed Codon: CCG
# Mutant Residue: P
#
# 17-D16_A03_031.seq
# Sequenced Codon: AGC
# Check Codon: GAT
# Transcribed Codon: AGC
# Mutant Residue: S
#
# 11-D9_C02_012.seq
# Sequenced Codon: GCG
# Check Codon: GAT
# Transcribed Codon: GCG
# Mutant Residue: A
#
# 08-D5_H01_001.seq
# Sequenced Codon: ACG
# Check Codon: GAT
# Transcribed Codon: ACG
# Mutant Residue: T
#
# 04-D1_D01_009.seq
# Sequenced Codon: GGG
# Check Codon: GAT
# Transcribed Codon: GGG
# Mutant Residue: G
#
# 16-D15_H02_002.seq
# Sequenced Codon: TGG
# Check Codon: GAT
# Transcribed Codon: UGG
# Mutant Residue: W
#
# 03-D20_C01_011.seq
# Sequenced Codon: GAG
# Check Codon: GAT
# Transcribed Codon: GAG
# Mutant Residue: E
#
# 01-D18_A01_015.seq
# Sequenced Codon: GGC
# Check Codon: GAT
# Transcribed Codon: GGC
# Mutant Residue: G
